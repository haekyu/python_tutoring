# %% [markdown]
# ### algorithm
# + input
# + 과정 : input 이라는 데이터 + 연산
# + output

# %% [markdown]
# ***
# ### 데이터
# + Data types
#     - primitive data type
#     - series data type
#     - 내가 디자인한 data type
#
# - primitive data type
#     + 숫자
#         - int: 정수
#             + -3, 2, 1, 0, ...
#         - float: 실수
#             + 3.14...., -3.23423
#     + 문자
#         - string
#             + "abc", "555", "한글", "ㄴㅇㄹ234sdf"
#             + 'abc', '555', '한글', 'ㄴㅇㄹ234sdf'
#     + 참거짓
#         - Boolean 혹은 Bool 이라 부름
#         - True / False
#         + True / False == 1 / 0
# - 형 변환
#     - 321 -> "321" -> 321
#     - 321.0 -> 321 -> 321.0
#     - str(True) == 'True'
#     - float(321) == 321.0
#     - int(321.7) == 321
#         == 버림
#         + cf) round(3.61) == 4 (반올림)

# %% [markdown]
# ***
# ### 연산
# - 연산자 == operator
# - 연산의 input == operand
# - primitive data type의 연산
#     - Boolean
#         + not
#             - not (True) == False
#         + and (== 교집합, *)
#             + True and True == True
#             + True and False == False
#             + False and True == False
#             + False and False == False
#         + or (== 합집합, +)
#             + True or True == True
#             + True or False == True
#             + False or True == True
#             + False or False == False
#         + True and (False and True) == False
#     - 숫자 (int, float)
#         + 사칙연산: + - * /
#         + modular: % == (~으로 나눈 나머지)
#             - 5 % 2 == 1
#             - 3.4 % 2 == 1.4
#         + 몫: //
#             - 5 // 2 == 2
#     - 문자
#         + 사칙연산 비슷한 것들
#             + +
#                 - concatenate
#                 - 예시)
#                     ```
#                     >>> "abc" + "321"
#                     "abc321"
#                     ```
#             + \*
#                 - multiply
#                 - 예시)
#                     ```
#                     >>> "abc" * 3
#                     "abcabcabc"
#                     ```
#         + sequence 관점에서의 연산자
#             + len()
#                 + s = "abc"
#                 + len(s) == 3
#                 + len("sdfsdfs") == 7
#             + 순서? 몇 번째 글자?
#                 + 대괄호! + 인덱스가 뭔지 + 인덱스 범위 표현 방식!
#                 + index == 몇 번째 순서 (숫자)
#                     + !!!!!!!!! index는 0부터 시작
#                     + "abcde".index("c") == 2
#                 + 인덱스 얻기?
#                     - 원하는 문자의 인덱스(위치) 얻기
#                     - "abcde".index("c") == 2
#                     - "abcde".find("c") == 2
#                 + indexing
#                     + index 번째 위치의 글자를 가져오는 행위
#                     + "abcdef"[3] == "d"
#                     + "abcdef"[-1] == "f"
#                 + slicing
#                     + index 범위의 글자들을 가져오는 행위
#                     + range 표현: [<from 이상> : <to 미만>]
#                     + "abcdef"[0 : 4] == "abcd"
#                     + 예제
#                         ```
#                         >>> s = "abcde"
#                         >>> s[-3: -1]
#                         'cd'
#                         ```
#                         ```
#                         >>> s[-3: 0]
#                         ''
#                         ```
#                         ```
#                         >>> s[-3: ]
#                         'cde'
#                         ```
#                         ```
#                         >>> s[:]
#                         'abcde'
#                         ```
#                         ```
#                         >>> s[:3]
#                         'abc'
#                         ```
# - 다른 연산자
#     + 비교 연산자
#         + ==: equals?
#         + !=: not equals?
#             + 3 != 4
#             + not (3 == 4)
#         + >
#             - 예제 1) string 사이의 비교연산: 사전 배열상 순서로 비교
#                 ```
#                 >>> "abf" > "aaa3"
#                 True
#                 ```
#             - 예제 2) Boolean 사이의 비교연산: True == 1, False == 0 이라 가정하고 비교
#                 ```
#                 >>> True >= True
#                 True
#                 ```
#                 ```
#                 >>> False >= True
#                 False
#                 ```
#         + <
#         + \>=
#         + <=
#     + Assign 연산
#         - assign 한다 == 값을 준다? == 값을 대입한다 == define 한다
#         + 변수
#             + x = 3
#             + x라는 변수에다가 3이라는 값을 대입
#         + 변수이름 규칙
#             - 조합: {a-z, A-Z, 0-9, _}: 영어 숫자 언더바
#                 + space XXXXXXXXXXX
#                 + tab XXXXXXXXXX
#                 + ! XXXXX
#                 + ? XXXXX
#                 + \- XXXXX
#             - 규칙
#                 + 영어 먼저!
#             - 변수의 이름 지을 때 정보가 잘 드러나도록 신경써서 지을 것!
#             - 예)
#                 + x, myStr3434ing, my___String2, mysTrgin242342
#                 + berry_is_Abbysinian
#                 + berryIsAbbysinian
#                 + a, b, c, d, e, idx_of_this_lst, iotl
#                 + list -> lst
#                 + index -> idx
#                 + maximum -> max

# %% [markdown]
# ***
# ### List
# - Series data type
#     - list !!!!!
#     - tuple
#     - array
# - list 만드는 규칙
#     + 대괄호로 열고 닫고
#     + 대괄호 안에 원소들을 순서대로 나열함
#     + 각각 원소는 , 로 구분
#     + 예시)
#         - empty_lst = []
#         - lst = [1, 2, 3, 4]
#         - lst2 = [4, 3, '2', 1, 'ㅇ', True, [3,2, 1]]
#         - 이때, lst != lst2
# - List는 Sequence!
#     - len(lst)
#     - index
#         + 0으로 시작!
#     - indexing
#         + lst[0]
#     - slicing
#         + [from 이상 : to 미만]
# - list 연산
#     - +, \* 가능
# - list의 함수
#     - 어떤리스트.append(덧붙이고싶은 원소)
#     - 어떤리스트.index('a')

# %% [markdown]
# ***
# ### 괄호 정리
# - [ ]
#     - list 를 정의할 때
#     - 인덱스를 감쌀 때
# - ( )
#     - 함수의 인풋을 감쌀 때
